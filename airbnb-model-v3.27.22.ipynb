# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import os

from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit

# 한글 폰트 설정 - window, mac
#plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.family'] = 'AppleGothic'

plt.rcParams['axes.unicode_minus'] = False ## 마이너스 부호 깨짐 방지

# %%
# 데이터 불러오기

# %%
def set_random_seed(seed):
    np.random.seed(seed)
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
random_seed = 1106
set_random_seed(random_seed)

# %%
## sessions
df = pd.read_csv('sessions.csv')
train = pd.read_csv('train_users_2.csv')
train.rename(columns={'id':'user_id'},inplace=True)

# %%
train['timestamp_first_active'] = pd.to_datetime(train['timestamp_first_active'], format = '%Y%m%d%H%M%S')
train['date_account_created'] = pd.to_datetime(train['date_account_created'])
train['date_first_booking'] = pd.to_datetime(train['date_first_booking'], errors='coerce')

# %% [markdown]
# # sessions 전처리 (df)

# %%
train_user_ids = set(train['user_id'])

# session 데이터에서 train 데이터에 존재하는 user_id만 필터링하여 사용
df = df[df['user_id'].isin(train_user_ids)]
df
# Out:
#             user_id            action action_type        action_detail  \
# 0        d1mm9tcy42            lookup         NaN                  NaN
# 1        d1mm9tcy42    search_results       click  view_search_results
# 2        d1mm9tcy42            lookup         NaN                  NaN
# 3        d1mm9tcy42    search_results       click  view_search_results
# 4        d1mm9tcy42            lookup         NaN                  NaN
# ...             ...               ...         ...                  ...
# 5555275  nw9fwlyb5f             index        data         reservations
# 5555276  nw9fwlyb5f  unavailabilities        data    unavailable_dates
# 5555277  nw9fwlyb5f     notifications      submit        notifications
# 5555278  nw9fwlyb5f            search       click  view_search_results
# 5555279  nw9fwlyb5f            search       click  view_search_results
#
#              device_type  secs_elapsed
# 0        Windows Desktop         319.0
# 1        Windows Desktop       67753.0
# 2        Windows Desktop         301.0
# 3        Windows Desktop       22141.0
# 4        Windows Desktop         435.0
# ...                  ...           ...
# 5555275           iPhone         245.0
# 5555276           iPhone         286.0
# 5555277           iPhone         830.0
# 5555278           iPhone      101961.0
# 5555279           iPhone       10863.0
#
# [5537957 rows x 6 columns]

# %%
# 'NDF'인 경우에는 0으로, 그 외의 경우에는 1로 값을 갖는 바이너리 타겟 열 생성

# session 데이터와 train 데이터 간의 공통된 user_id를 찾습니다.
common_user_ids = set(train['user_id']).intersection(set(df['user_id']))
# train 데이터에 있는 user_id와 매칭되는 session user에게 binary_target 값을 설정합니다.
df['binary_target'] = df['user_id'].isin(common_user_ids).astype(int)
train['binary_target'] = (train['country_destination'] != 'NDF').astype(int)

# %%
df['action_flow'] = df['action'].astype('str') + '+' + df['action_type'].astype('str') + '+' + df['action_detail'].astype('str')

# %% [markdown]
# ## 유저별 action order 생성
# 각 유저별 action_order 열에 로그 순서(1~) 입력

# %%
df['action_order'] = df.groupby('user_id').cumcount() + 1

# %% [markdown]
# ## 유저 elapsed time 변경
# 이전행부터 현재행까지 측정된 시간 -> 현재 액션의 총 걸린 시간으로 변경

# %%
# 한 칸씩 위로 당겨오기
df['secs_elapsed'] = df['secs_elapsed'].shift(-1)
# 유저별 마지막 elapsed time은 측정되지 않았으므로 nan
last_order = df.groupby('user_id').tail(1).index
df.loc[last_order, 'secs_elapsed'] = np.NaN

# %% [markdown]
# # 액션 EDA
#
# 만약 예약 유저만 사용한 action이 있다면 예약과 비예약 예측에 활용

# %% [markdown]
# ## session에 유저의 인덱스가 섞여 있는지 확인
# result: 각 유저별로 로그 index가 끊어지지 않도록 존재한다.

# %%
def count_user_chages(df):
    count=0
    prev_user_id = None

    for user_id in df['user_id']:
        if prev_user_id is None:
            prev_user_id = user_id
        elif user_id != prev_user_id:
            count+=1
            prev_user_id = user_id
    if prev_user_id is not None:
        count +=1
    return count

result = count_user_chages(df)
print(result)
# Out:
# 73815

# %%
len(df['user_id'].unique())
# Out:
# 73815

# %% [markdown]
# ## 액션 타입별 flow 개수

# %%
max_length = max(len(str(i)) for i in df['action_type'].unique())

for i in df['action_type'].unique():
    print('action type:',str(i).ljust(max_length),' ','action combination count =',len(df[df['action_type']==i]['action_flow'].unique()))
# Out:
# action type: nan                action combination count = 0
# action type: click              action combination count = 35
# action type: data               action combination count = 19
# action type: view               action combination count = 52
# action type: submit             action combination count = 30
# action type: message_post       action combination count = 10
# action type: -unknown-          action combination count = 234
# action type: booking_request    action combination count = 2
# action type: partner_callback   action combination count = 1
# action type: booking_response   action combination count = 1

# %%
## 액션별 예약 유저의 유니크한 수 확인 -> 예약 유저들이 사용한 action의 비중
## booking_df = df[df['binary_target']==1], action_columns: action, action_type, action_detail
def action_count_with_booking_users(booking_df,action_column):
    # 각 액션별로 고유한 사용자 수를 계산
    unique_users_per_flow = booking_df.groupby(action_column)['user_id'].nunique()
    
    # 총 사용자 수를 계산
    total_unique_users = booking_df['user_id'].nunique()
    
    # DataFrame 생성
    result_df = pd.DataFrame({
        'user_count': unique_users_per_flow,
        'ratio': unique_users_per_flow / total_unique_users
    })
    
    # 고유한 사용자 수에 따라 플로우를 내림차순으로 정렬
    sorted_result_df = result_df.sort_values(by='user_count', ascending=False)
    
    # 결과 출력
    print(sorted_result_df)

# %%
booking_df = df[df['binary_target']==1]
action_count_with_booking_users(booking_df,'action')
print('\n')
action_count_with_booking_users(booking_df,'action_type')
print('\n')
action_count_with_booking_users(booking_df,'action_detail')
print('\n')
# Out:
#                        user_count     ratio
# action
# show                        57394  0.777538
# header_userpic              56853  0.770209
# create                      49341  0.668441
# index                       47792  0.647456
# personalize                 42556  0.576522
# ...                           ...       ...
# reactivate                      1  0.000014
# special_offer                   1  0.000014
# southern-europe                 1  0.000014
# acculynk_load_pin_pad           1  0.000014
# toggle_availability             1  0.000014
#
# [331 rows x 2 columns]
#
#
#                   user_count     ratio
# action_type
# submit                 68915  0.933618
# data                   68139  0.923105
# view                   65428  0.886378
# click                  59251  0.802696
# -unknown-              56216  0.761580
# message_post           27919  0.378229
# booking_request        10003  0.135514
# partner_callback        5334  0.072262
# booking_response           2  0.000027
#
#
#                             user_count     ratio
# action_detail
# header_userpic                   56853  0.770209
# -unknown-                        56216  0.761580
# p3                               48500  0.657048
# view_search_results              43892  0.594622
# wishlist_content_update          42556  0.576522
# ...                                ...       ...
# delete_listing_description           3  0.000041
# booking                              2  0.000027
# host_respond                         2  0.000027
# special_offer_field                  1  0.000014
# tos_2014                             1  0.000014
#
# [128 rows x 2 columns]

# %% [markdown]
# # train_with_sessions_data 그룹(sessions에 user_id를 갖는 train 데이터)
# 세션 데이터가 있는 유저는 2014.01.01년부터 존재
#
# 1. 날짜 관련 데이터 -> 기간 변경('date_account_created', 'timestamp_first_active', 'date_first_booking')
# 2014년의 특수성을 제외하기 위해 첫 접속 및 가입으로부터 예약까지의 기간 등을 살펴보고자 함
# 상관관계를 통해 기간에 따른 변화를 살펴보고 날짜에서 범주형 기간으로 변경
# 2. 성별(그대로 사용)과 나이(43.7%-NaN)
# 3. 회원가입 - date_account_created(날짜), signup_method(사이트), signup_flow(페이지), signup_app(웹-어플) -> sign_up
# 4. 첫 접속과 관련된 정보 - timestamp_first_active(접속 날짜), first_affiliate_tracked(untracked 대부분), first_device_type(데스크탑-모바일) 범주화
# 5. 접속 경로 - affiliate_channel(채널),  affiliate_provider(채널 제공자) => channel_flow
#
# 6. 액션 - (action, type, detail), device_type(사용 장비), secs_elapsed(액션 경과 시간)
#
# action에서 nan   -> unknown으로 변경
# secs_elapsed nan -> 0으로 변경

# %% [markdown]
# ## 피쳐 탐색 함수

# %%
def count_ratio(df,column):
    group_df = df.groupby(column)['binary_target']
    ratio = group_df.mean()
    count = group_df.count()
    count.sort_values(ascending=False,inplace=True)
    sorted_ratio = ratio[count.index]

    fig, ax1 = plt.subplots(figsize=(10, 6))
    # 막대 그래프 (왼쪽 y축)
    count.plot(kind='bar', color='skyblue', alpha=0.7, label='count', ax=ax1)
    ax1.set_ylabel('count')
    #ax1.set_yscale('log')
    # 오른쪽 y축 추가
    ax2 = ax1.twinx()
    sorted_ratio.plot(kind='line', color='red', marker='o', label=' ratio', ax=ax2)
    ax2.set_ylabel('ratio')
    ax2.set_ylim(0,1.2)
    
    # 제목 및 범례 추가
    plt.title('count & booking ratio')
    
    # 그리드 추가
    ax1.grid(axis='y', linestyle='--', alpha=0.7)
    
    # 범례 위치 조정
    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax2.legend(lines + lines2, labels + labels2, loc='upper right')
    plt.show()

# %%
# sessions 데이터프레임에서 user_id만 추출하여 set으로 변환
sessions_user_ids = set(sessions['user_id'])

# train 데이터프레임에서 sessions에 있는 user_id만을 필터링
train_with_sessions_data = train[train['user_id'].isin(sessions_user_ids)]
train_with_sessions_data
# Out:
#            user_id date_account_created timestamp_first_active  \
# 137021  d1mm9tcy42           2014-01-01    2014-01-01 00:09:36
# 137022  yo8nz8bqcq           2014-01-01    2014-01-01 00:15:58
# 137023  4grx6yxeby           2014-01-01    2014-01-01 00:16:39
# 137024  ncf87guaf0           2014-01-01    2014-01-01 00:21:46
# 137025  4rvqpxoh3h           2014-01-01    2014-01-01 00:26:19
# ...            ...                  ...                    ...
# 213446  zxodksqpep           2014-06-30    2014-06-30 23:56:36
# 213447  mhewnxesx9           2014-06-30    2014-06-30 23:57:19
# 213448  6o3arsjbb4           2014-06-30    2014-06-30 23:57:54
# 213449  jh95kwisub           2014-06-30    2014-06-30 23:58:22
# 213450  nw9fwlyb5f           2014-06-30    2014-06-30 23:58:24
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 137021         2014-01-04       MALE  62.0         basic            0
# 137022                NaT  -unknown-   NaN         basic            0
# 137023                NaT  -unknown-   NaN         basic            0
# 137024                NaT  -unknown-   NaN         basic            0
# 137025         2014-01-02  -unknown-   NaN         basic           25
# ...                   ...        ...   ...           ...          ...
# 213446                NaT       MALE  32.0         basic            0
# 213447                NaT  -unknown-   NaN         basic            0
# 213448                NaT  -unknown-  32.0         basic            0
# 213449                NaT  -unknown-   NaN         basic           25
# 213450                NaT  -unknown-   NaN         basic           25
#
#        language affiliate_channel affiliate_provider first_affiliate_tracked  \
# 137021       en     sem-non-brand             google                     omg
# 137022       en            direct             direct               untracked
# 137023       en         sem-brand             google                     omg
# 137024       en            direct             direct                  linked
# 137025       en            direct             direct               untracked
# ...         ...               ...                ...                     ...
# 213446       en         sem-brand             google                     omg
# 213447       en            direct             direct                  linked
# 213448       en            direct             direct               untracked
# 213449       en             other              other           tracked-other
# 213450       en            direct             direct               untracked
#
#        signup_app first_device_type  first_browser country_destination  \
# 137021        Web   Windows Desktop         Chrome               other
# 137022        Web       Mac Desktop        Firefox                 NDF
# 137023        Web   Windows Desktop        Firefox                 NDF
# 137024        Web   Windows Desktop         Chrome                 NDF
# 137025        iOS            iPhone      -unknown-                  GB
# ...           ...               ...            ...                 ...
# 213446        Web       Mac Desktop         Safari                 NDF
# 213447        Web   Windows Desktop         Chrome                 NDF
# 213448        Web       Mac Desktop        Firefox                 NDF
# 213449        iOS            iPhone  Mobile Safari                 NDF
# 213450        iOS            iPhone      -unknown-                 NDF
#
#         binary_target
# 137021              1
# 137022              0
# 137023              0
# 137024              0
# 137025              1
# ...               ...
# 213446              0
# 213447              0
# 213448              0
# 213449              0
# 213450              0
#
# [73815 rows x 17 columns]

# %% [markdown]
# ## train_with_sessions_data 피쳐 생성

# %%
train_with_sessions_data = train_with_sessions_data.copy()
train_with_sessions_data['sign_up'] = train_with_sessions_data['signup_method'].astype('str') + '+' + train_with_sessions_data['signup_flow'].astype('str') + '+' + train_with_sessions_data['signup_app'].astype('str')
train_with_sessions_data['channel_flow'] = train_with_sessions_data['affiliate_channel'].astype('str') + '+' + train_with_sessions_data['affiliate_provider'].astype('str')

# %%
train_with_sessions_data['age'].isnull().sum()
# Out:
# 32248

# %% [markdown]
# ## 나이별 분포
# airbnb 정책: 18세 미만은 예약이 불가능 -> error
# 방법: 18세 미만 -> 0으로 대체
# 100세 이상 -> unknown으로 묶자 ex 100

# %%
train_with_sessions_data[(train_with_sessions_data['age']<19)].groupby('age')['binary_target'].agg(['count','mean'])
# Out:
#       count      mean
# age
# 1.0       1  0.000000
# 2.0       1  0.000000
# 15.0      3  0.333333
# 16.0     13  0.076923
# 17.0     33  0.030303
# 18.0    190  0.489474

# %%
plt.figure(figsize=(15,8))

group_df = train_with_sessions_data[(train_with_sessions_data['age']<101)].groupby('age')['binary_target']
ratio = group_df.mean()
count = group_df.count()

fig, ax1 = plt.subplots(figsize=(10, 6))
# 막대 그래프 (왼쪽 y축)
ax1.bar(count.index,count, color='skyblue', alpha=0.7, label='count')
ax1.set_ylabel('count')
#ax1.set_yscale('log')

# 오른쪽 y축 추가
ax2 = ax1.twinx()
ax2.plot(ratio.index,ratio ,color='red', marker='o', label=' ratio')
ax2.set_ylabel('ratio')

# 제목 및 범례 추가
plt.title('count & booking ratio')
plt.xlim(17,101)

ax2.grid(axis='y', linestyle='--', alpha=0.7)
# 범례 위치 조정
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 컬럼별 인원 수와 예약 비율

# %%
for i in train_with_sessions_data.columns[6:]:
    count_ratio(train_with_sessions_data,i)

# %% [markdown]
# # catboost 머신러닝

# %%
train_with_sessions_data.columns
# Out:
# Index(['user_id', 'date_account_created', 'timestamp_first_active',
#        'date_first_booking', 'gender', 'age', 'signup_method', 'signup_flow',
#        'language', 'affiliate_channel', 'affiliate_provider',
#        'first_affiliate_tracked', 'signup_app', 'first_device_type',
#        'first_browser', 'country_destination', 'binary_target', 'sign_up',
#        'channel_flow'],
#       dtype='object')

# %%
# 데이터 준비
X = train_with_sessions_data.drop(['user_id','date_first_booking','country_destination','binary_target'], axis=1)  # 입력 특징
y = train_with_sessions_data['binary_target']  # 목표 변수

# 숫자가 아닌 타입의 열을 찾아서 cat_features에 추가
cat_features = [col for col in X.columns if X[col].dtype not in ['int64', 'float64']]
for col in cat_features:
    X[col] = X[col].astype(str)

# 훈련 데이터와 테스트 데이터로 나누기
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=random_seed)
for train_index, test_index in sss.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# CatBoost 모델 초기화
model = CatBoostClassifier(iterations=100,learning_rate=0.03, depth=6, loss_function='Logloss', eval_metric='Accuracy', random_seed=random_seed)

# 모델 학습
model.fit(X_train, y_train, cat_features=cat_features)
#y_pred = pd.Series(y_pred)

# 테스트 데이터 예측
y_pred = model.predict(X_test)
y_pred = pd.Series(y_pred)
# 정확도 평가
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# 0:	learn: 0.7196708	total: 20.2ms	remaining: 2s
# 1:	learn: 0.7196708	total: 41.4ms	remaining: 2.03s
# 2:	learn: 0.7196708	total: 62.9ms	remaining: 2.03s
# 3:	learn: 0.7197555	total: 78.1ms	remaining: 1.87s
# 4:	learn: 0.7197555	total: 97.9ms	remaining: 1.86s
# 5:	learn: 0.7196877	total: 116ms	remaining: 1.82s
# 6:	learn: 0.7197385	total: 132ms	remaining: 1.76s
# 7:	learn: 0.7197047	total: 149ms	remaining: 1.71s
# 8:	learn: 0.7196708	total: 164ms	remaining: 1.66s
# 9:	learn: 0.7196708	total: 178ms	remaining: 1.6s
# 10:	learn: 0.7196708	total: 192ms	remaining: 1.56s
# 11:	learn: 0.7196877	total: 208ms	remaining: 1.53s
# 12:	learn: 0.7197724	total: 226ms	remaining: 1.51s
# 13:	learn: 0.7197893	total: 253ms	remaining: 1.56s
# 14:	learn: 0.7197724	total: 271ms	remaining: 1.53s
# 15:	learn: 0.7197047	total: 285ms	remaining: 1.5s
# 16:	learn: 0.7197047	total: 299ms	remaining: 1.46s
# 17:	learn: 0.7197385	total: 313ms	remaining: 1.43s
# 18:	learn: 0.7197385	total: 327ms	remaining: 1.4s
# 19:	learn: 0.7197385	total: 342ms	remaining: 1.37s
# 20:	learn: 0.7197216	total: 355ms	remaining: 1.34s
# 21:	learn: 0.7197216	total: 369ms	remaining: 1.31s
# 22:	learn: 0.7197216	total: 383ms	remaining: 1.28s
# 23:	learn: 0.7197555	total: 397ms	remaining: 1.26s
# 24:	learn: 0.7197385	total: 411ms	remaining: 1.23s
# 25:	learn: 0.7197216	total: 426ms	remaining: 1.21s
# 26:	learn: 0.7197555	total: 442ms	remaining: 1.19s
# 27:	learn: 0.7197216	total: 465ms	remaining: 1.2s
# 28:	learn: 0.7196539	total: 483ms	remaining: 1.18s
# 29:	learn: 0.7196369	total: 499ms	remaining: 1.16s
# 30:	learn: 0.7197047	total: 517ms	remaining: 1.15s
# 31:	learn: 0.7196708	total: 533ms	remaining: 1.13s
# 32:	learn: 0.7196877	total: 550ms	remaining: 1.12s
# 33:	learn: 0.7197047	total: 566ms	remaining: 1.1s
# 34:	learn: 0.7196708	total: 585ms	remaining: 1.08s
# 35:	learn: 0.7196877	total: 602ms	remaining: 1.07s
# 36:	learn: 0.7197047	total: 621ms	remaining: 1.06s
# 37:	learn: 0.7196877	total: 647ms	remaining: 1.06s
# 38:	learn: 0.7197724	total: 677ms	remaining: 1.06s
# 39:	learn: 0.7197216	total: 694ms	remaining: 1.04s
# 40:	learn: 0.7197555	total: 712ms	remaining: 1.02s
# 41:	learn: 0.7197385	total: 729ms	remaining: 1.01s
# 42:	learn: 0.7196877	total: 746ms	remaining: 989ms
# 43:	learn: 0.7197216	total: 762ms	remaining: 970ms
# 44:	learn: 0.7197047	total: 780ms	remaining: 953ms
# 45:	learn: 0.7197047	total: 798ms	remaining: 937ms
# 46:	learn: 0.7197216	total: 815ms	remaining: 920ms
# 47:	learn: 0.7197047	total: 834ms	remaining: 904ms
# 48:	learn: 0.7197555	total: 853ms	remaining: 888ms
# 49:	learn: 0.7197216	total: 871ms	remaining: 871ms
# 50:	learn: 0.7197724	total: 891ms	remaining: 856ms
# 51:	learn: 0.7197385	total: 915ms	remaining: 844ms
# 52:	learn: 0.7197724	total: 934ms	remaining: 828ms
# 53:	learn: 0.7197555	total: 951ms	remaining: 810ms
# 54:	learn: 0.7197555	total: 966ms	remaining: 791ms
# 55:	learn: 0.7197555	total: 983ms	remaining: 773ms
# 56:	learn: 0.7197724	total: 998ms	remaining: 753ms
# 57:	learn: 0.7197385	total: 1.02s	remaining: 737ms
# 58:	learn: 0.7197724	total: 1.03s	remaining: 719ms
# 59:	learn: 0.7197893	total: 1.05s	remaining: 700ms
# 60:	learn: 0.7198063	total: 1.07s	remaining: 683ms
# 61:	learn: 0.7198063	total: 1.09s	remaining: 669ms
# 62:	learn: 0.7198063	total: 1.11s	remaining: 654ms
# 63:	learn: 0.7198232	total: 1.13s	remaining: 634ms
# 64:	learn: 0.7198232	total: 1.14s	remaining: 614ms
# 65:	learn: 0.7197893	total: 1.16s	remaining: 595ms
# 66:	learn: 0.7198571	total: 1.17s	remaining: 576ms
# 67:	learn: 0.7198740	total: 1.18s	remaining: 557ms
# 68:	learn: 0.7198063	total: 1.2s	remaining: 539ms
# 69:	learn: 0.7199079	total: 1.21s	remaining: 520ms
# 70:	learn: 0.7198740	total: 1.23s	remaining: 501ms
# 71:	learn: 0.7199248	total: 1.24s	remaining: 483ms
# 72:	learn: 0.7199248	total: 1.25s	remaining: 464ms
# 73:	learn: 0.7200095	total: 1.27s	remaining: 447ms
# 74:	learn: 0.7200603	total: 1.29s	remaining: 430ms
# 75:	learn: 0.7200603	total: 1.31s	remaining: 414ms
# 76:	learn: 0.7200603	total: 1.33s	remaining: 397ms
# 77:	learn: 0.7200095	total: 1.34s	remaining: 379ms
# 78:	learn: 0.7200095	total: 1.36s	remaining: 361ms
# 79:	learn: 0.7200942	total: 1.38s	remaining: 344ms
# 80:	learn: 0.7200603	total: 1.39s	remaining: 327ms
# 81:	learn: 0.7200095	total: 1.41s	remaining: 309ms
# 82:	learn: 0.7200264	total: 1.43s	remaining: 292ms
# 83:	learn: 0.7200264	total: 1.44s	remaining: 275ms
# 84:	learn: 0.7200603	total: 1.46s	remaining: 257ms
# 85:	learn: 0.7200772	total: 1.47s	remaining: 240ms
# 86:	learn: 0.7201450	total: 1.49s	remaining: 223ms
# 87:	learn: 0.7201450	total: 1.51s	remaining: 206ms
# 88:	learn: 0.7201619	total: 1.52s	remaining: 188ms
# 89:	learn: 0.7202296	total: 1.54s	remaining: 171ms
# 90:	learn: 0.7203143	total: 1.55s	remaining: 153ms
# 91:	learn: 0.7202804	total: 1.56s	remaining: 136ms
# 92:	learn: 0.7202804	total: 1.58s	remaining: 119ms
# 93:	learn: 0.7202974	total: 1.6s	remaining: 102ms
# 94:	learn: 0.7202974	total: 1.62s	remaining: 85.2ms
# 95:	learn: 0.7203482	total: 1.63s	remaining: 68.1ms
# 96:	learn: 0.7202974	total: 1.65s	remaining: 51ms
# 97:	learn: 0.7203143	total: 1.66s	remaining: 34ms
# 98:	learn: 0.7203143	total: 1.68s	remaining: 17ms
# 99:	learn: 0.7203143	total: 1.7s	remaining: 0us
# Accuracy: 0.7090022353180248

# %%
feature_importances = model.feature_importances_

# 피처 이름과 중요도를 함께 출력
for feature_name, importance in zip(X_train.columns, feature_importances):
    print(f"Feature: {feature_name}, Importance: {importance}")
# Out:
# Feature: date_account_created, Importance: 0.05379333908237902
# Feature: timestamp_first_active, Importance: 0.0
# Feature: gender, Importance: 2.7319715303967094
# Feature: age, Importance: 64.6009435122489
# Feature: signup_method, Importance: 14.082946961463753
# Feature: signup_flow, Importance: 0.22652968345857835
# Feature: language, Importance: 0.6311763160957611
# Feature: affiliate_channel, Importance: 2.4159131590868426
# Feature: affiliate_provider, Importance: 0.2569287304244167
# Feature: first_affiliate_tracked, Importance: 0.3813572607423719
# Feature: signup_app, Importance: 1.8214407382838573
# Feature: first_device_type, Importance: 1.8912962014261625
# Feature: first_browser, Importance: 3.3397623225358677
# Feature: sign_up, Importance: 5.219960545001319
# Feature: channel_flow, Importance: 2.34597969975307
